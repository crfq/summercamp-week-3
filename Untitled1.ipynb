# %% [markdown]
# <a href="https://colab.research.google.com/github/crfq/summercamp-week-3/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt
conexion = sqlite3.connect("torneo_smash.db")
df_original = pd.read_csv("smash_dataset_clean.csv", encoding="latin1")
df_original.to_sql("combates", conexion, if_exists="replace", index=False)
print("✅ ¡Éxito total! La base de datos relacional 'torneo_smash.db' ha sido creada y la tabla 'combates' está lista.")

consulta_sql = """
SELECT Nombre, Personaje, KOs, Muertes
FROM combates
ORDER BY Muertes DESC
"""

df_filtrado = pd.read_sql_query(consulta_sql, conexion)

print("📊 Datos extraídos mediante SQL con éxito:")
df_filtrado.head(10)
# Out:
# ✅ ¡Éxito total! La base de datos relacional 'torneo_smash.db' ha sido creada y la tabla 'combates' está lista.
# 📊 Datos extraídos mediante SQL con éxito:
#      Nombre       Personaje  KOs  Muertes
# 0      Fred     Donkey Kong  1.0      4.0
# 1    Adrian      Incineroar  1.0      2.0
# 2       Ale           Kirby  1.0      2.0
# 3  Leonardo           shulk  2.0      2.0
# 4    Daniel      Metaknight  3.0      2.0
# 5    Laura            Kirby  0.0      2.0
# 6    Andres           Samus  1.0      2.0
# 7   Gabriel      Little mac  2.0      2.0
# 8    Carlos  Game and watch  2.0      2.0
# 9   Gabriel      Little mac  3.0      1.0

# %%
sns.set_theme(style="white")


plt.figure(figsize=(12, 6))


grafico_barras = sns.barplot(
    data=df_filtrado,
    x="Nombre",
    y="Muertes",
    palette="magma",
    estimator='sum',
    errorbar=None
)


plt.title("🥊 Récord Absoluto de Muertes por Participante", fontsize=16, fontweight="bold", pad=15)
plt.xlabel("Héroes del Aula CLIC", fontsize=12, labelpad=10)
plt.ylabel("Cantidad de Muertes Totales", fontsize=12, labelpad=10)


plt.xticks(rotation=45)


plt.show()
# Out:
# /tmp/ipykernel_23117/37235668.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   grafico_barras = sns.barplot(
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129354 (\N{BOXING GLOVE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
