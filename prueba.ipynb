# %% [markdown]
# <a href="https://colab.research.google.com/github/crfq/summercamp-week-3/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Summer Camp 2026")
# Out:
# Summer Camp 2026

# %%
jugador = "Game and Watch"
print (jugador,"Ha entrado en la arena")
jugador2 = "Kirby"
print (jugador2,"se ha caido del escenario")
# Out:
# Game and Watch Ha entrado en la arena
# Kirby se ha caido del escenario
